# %%
import torch
import glob
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
dir_data = "../log_files/BAT-clean_adv_distribution-Madry_loss/BAT-clean_adv_distribution-Madry_loss-Madry_loss--epochs_110-weight_decay_0.0005-lr_max_0.1-epsilon_0.06274509803921569-num_steps_10-step_size_0.00784313725490196-seed_0-/20220410131028_y63mvmvg"

all_data = [torch.load(os.path.join(dir_data, f"dis_measure_{i}.pth")) for i in range(1, 111)]

# %%
avg_all_data = np.average([i['bn1.bn_list.0.running_mean'] for i in all_data])

# %%
avg_all_data
# Out:
# 0.0012026852482480339

# %%
plt.figure()
plt.plot([i['bn1.bn_list.0.running_mean'] for i in all_data])

# %%
all_keys = all_data[0].keys()

# %%
for key in list(all_keys):
    plt.figure()
    plt.plot([i[key] for i in all_data])
    plt.title(key)
# Out:
# /tmp/ipykernel_5129/1495956966.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
